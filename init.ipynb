# %%
pip install -e .
# Out:
# Obtaining file:///home/onyxia/work/Advanced_ML_Ensae
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for Adv_ML (pyproject.toml) ... done
#   Created wheel for Adv_ML: filename=Adv_ML-0.1.0-0.editable-py3-none-any.whl size=2752 sha256=ee6cb08dadd0525f0e4eb4f76393da7b479c145ffb453d9e88a4fdb74db76121
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4nvkfjnk/wheels/90/13/52/332bd59be5a3b7619e94183c8f4308cbf8f3f04efa9acb15b8
# Successfully built Adv_ML
# ...
# Note: you may need to restart the kernel to use updated packages.
